# %% [markdown]
# 从网上下载rss文件

# %%
import requests
import os
import xml.etree.ElementTree as ET
name_list = ["miccai","isbi","mlmi","spiemi","smc","bibm","chil","bhi","bcb","amia","ipmi","cbms","ner","ichi","biostec","cinc","psb","miccai","icphm","memea","chase","bibe","bmei","recomb","mie","bsn","icbbe","icdh","miua","sipaim","cibcb","vcbm","aime","isbra","segah","ict4ageingwell"]
def parse_rss_items(conf_id):
    rss_url = f"https://dblp.uni-trier.de/feed/streams/conf/{conf_id}.rss"
    response = requests.get(rss_url)

    if response.status_code != 200:
        raise Exception(f"❌ Failed to fetch RSS: {response.status_code}")
    root = ET.fromstring(response.content)
    items = root.findall(".//item")

    result = []
    for item in items:
        title = item.find("title").text     # 如 "BSN 2024"
        link = item.find("link").text       # 如 https://dblp.org/db/conf/bsn/bsn2024.html
        result.append((title, link))
    return result

# %% [markdown]
# 从 dblp 链接中提取 conf_id 和年份，构造 API 地址并下载 JSON 文件

# %%
import os
import requests
import xml.etree.ElementTree as ET
import re
def parse_local_rss_file(file_path):
    """
    从本地 RSS 文件中提取 link 列表
    """
    tree = ET.parse(file_path)
    root = tree.getroot()
    items = root.findall(".//item")

    result = []
    for item in items:
        link = item.find("link").text.strip()
        result.append(link)
    return result
def parse_conf_year_from_link(link):
    """
    从 link 中提取 conf 和 year
    例：https://dblp.org/db/conf/bsn/bsn2024.html → ('bsn', '2024')
    """
    parts = link.strip().split("/")
    conf = parts[-2]
    filename = parts[-1].replace(".html", "")  # 如 bsn2024
    year_match = re.search(r'(\d{4})', filename)
    if year_match:
        year = year_match.group(1)
        return conf, year
    else:
        return conf, None  # 无年份信息

# %%
import time


def download_dblp_json_from_link(link, base_dir="data"):
    """
    从 link 构造 API 请求并保存为 data/{conf}/{conf}_{year}.json
    """
    conf, year = parse_conf_year_from_link(link)
    if not year:
        print(f"⚠️ 无法从链接中提取年份: {link}")
        return

    conf_year_id = f"{conf}{year}"
    query = f"toc:db/conf/{conf}/{conf_year_id}.bht:"
    url = f"https://dblp.org/search/publ/api?q={query}&h=1000&format=json"

    save_dir = os.path.join(base_dir, conf.upper())
    os.makedirs(save_dir, exist_ok=True)
    save_path = os.path.join(save_dir, f"{conf.upper()}_{year}.json")
    
    time.sleep(3)  # 避免请求过快导致被封禁
    response = requests.get(url)
    if response.status_code == 200:
        with open(save_path, "w", encoding="utf-8") as f:
            f.write(response.text)
        print(f"✅ Saved: {save_path}")
    else:
        print(f"❌ Failed: {conf}_{year} ({response.status_code})")

# %%
def download_all_from_local_rss(rss_file_path):
    """
    主函数：读取本地 RSS，逐个处理链接并下载 JSON
    """
    print(f"📂 正在读取本地 RSS 文件: {rss_file_path}")
    links = parse_local_rss_file(rss_file_path)
    print(f"🔍 共找到 {len(links)} 个年份链接")

    for link in links:
        print(f"➡️ 正在处理: {link}")
        download_dblp_json_from_link(link)

# %%
# miccai 不行
download_all_from_local_rss("rss/miccai.rss")
# Out:
# 📂 正在读取本地 RSS 文件: miccai.rss
# 🔍 共找到 281 个年份链接
# ➡️ 正在处理: https://dblp.org/db/conf/miccai
json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/csi2015.html
# ✅ Saved: data\MICCAI\MICCAI_2015.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/care2015.html
# ✅ Saved: data\MICCAI\MICCAI_2015.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/cdmri2013.html
# ✅ Saved: data\MICCAI\MICCAI_2013.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2015-1.html
# ✅ Saved: data\MICCAI\MICCAI_2015.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2015-2.html
# ✅ Saved: data\MICCAI\MICCAI_2015.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2015-3.html
# ✅ Saved: data\MICCAI\MICCAI_2015.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/stia2014.html
# ✅ Saved: data\MICCAI\MICCAI_2014.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/care2014.html
# ✅ Saved: data\MICCAI\MICCAI_2014.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2014-1.html
# ✅ Saved: data\MICCAI\MICCAI_2014.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2014-2.html
# ✅ Saved: data\MICCAI\MICCAI_2014.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2014-3.html
# ✅ Saved: data\MICCAI\MICCAI_2014.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/col2013.html
# ✅ Saved: data\MICCAI\MICCAI_2013.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2013-1.html
# ✅ Saved: data\MICCAI\MICCAI_2013.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2013-2.html
# ✅ Saved: data\MICCAI\MICCAI_2013.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2013-3.html
# ✅ Saved: data\MICCAI\MICCAI_2013.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/mcbr2012.html
# ✅ Saved: data\MICCAI\MICCAI_2012.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2012-1.html
# ✅ Saved: data\MICCAI\MICCAI_2012.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2012-2.html
# ✅ Saved: data\MICCAI\MICCAI_2012.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2012-3.html
# ✅ Saved: data\MICCAI\MICCAI_2012.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/stia2012.html
# ✅ Saved: data\MICCAI\MICCAI_2012.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/meshmed2012.html
# ✅ Saved: data\MICCAI\MICCAI_2012.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/col2012.html
# ✅ Saved: data\MICCAI\MICCAI_2012.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/col2011.html
# ✅ Saved: data\MICCAI\MICCAI_2011.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/mcbr2011.html
# ✅ Saved: data\MICCAI\MICCAI_2011.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/col2010.html
# ✅ Saved: data\MICCAI\MICCAI_2010.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/pci2011.html
# ✅ Saved: data\MICCAI\MICCAI_2011.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2011-1.html
# ✅ Saved: data\MICCAI\MICCAI_2011.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2011-2.html
# ✅ Saved: data\MICCAI\MICCAI_2011.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2011-3.html
# ✅ Saved: data\MICCAI\MICCAI_2011.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2010-2.html
# ✅ Saved: data\MICCAI\MICCAI_2010.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2010-3.html
# ✅ Saved: data\MICCAI\MICCAI_2010.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2010-1.html
# ✅ Saved: data\MICCAI\MICCAI_2010.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/pci2010.html
# ✅ Saved: data\MICCAI\MICCAI_2010.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/mcbr2009.html
# ✅ Saved: data\MICCAI\MICCAI_2009.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2009-1.html
# ✅ Saved: data\MICCAI\MICCAI_2009.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2009-2.html
# ✅ Saved: data\MICCAI\MICCAI_2009.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2008-2.html
# ✅ Saved: data\MICCAI\MICCAI_2008.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2008-1.html
# ✅ Saved: data\MICCAI\MICCAI_2008.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2007-1.html
# ✅ Saved: data\MICCAI\MICCAI_2007.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2007-2.html
# ✅ Saved: data\MICCAI\MICCAI_2007.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2006-1.html
# ✅ Saved: data\MICCAI\MICCAI_2006.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2006-2.html
# ✅ Saved: data\MICCAI\MICCAI_2006.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2005-2.html
# ✅ Saved: data\MICCAI\MICCAI_2005.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2005-1.html
# ✅ Saved: data\MICCAI\MICCAI_2005.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2004-2.html
# ✅ Saved: data\MICCAI\MICCAI_2004.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2004-1.html
# ✅ Saved: data\MICCAI\MICCAI_2004.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2003-2.html
# ✅ Saved: data\MICCAI\MICCAI_2003.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2003-1.html
# ✅ Saved: data\MICCAI\MICCAI_2003.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2002-2.html
# ✅ Saved: data\MICCAI\MICCAI_2002.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2002-1.html
# ✅ Saved: data\MICCAI\MICCAI_2002.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2001.html
# ✅ Saved: data\MICCAI\MICCAI_2001.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai2000.html
# ✅ Saved: data\MICCAI\MICCAI_2000.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai1999.html
# ✅ Saved: data\MICCAI\MICCAI_1999.json
# ➡️ 正在处理: https://dblp.org/db/conf/miccai/miccai1998.html
# ✅ Saved: data\MICCAI\MICCAI_1998.json
